# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %%
whale_file_path = Path('../../Desktop/RU-HOU-FIN-PT-07-2019-U-C/hw/03-Python_and_Pandas/Instructions/Resources/whale_returns.csv')
algo_file_path = Path('../../Desktop/RU-HOU-FIN-PT-07-2019-U-C/hw/03-Python_and_Pandas/Instructions/Resources/algo_returns.csv')
sp500_file_path = Path('../../Desktop/RU-HOU-FIN-PT-07-2019-U-C/hw/03-Python_and_Pandas/Instructions/Resources/sp500_history.csv')

# %%
whale_returns_csv = pd.read_csv(whale_file_path, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
whale_returns_csv.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_returns_csv.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
whale_returns_csv.sample(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2016-04-08                   0.003902           -0.005315
# 2015-08-31                  -0.003931           -0.003050
# 2017-09-07                  -0.001191           -0.001421
# 2017-09-15                  -0.000158           -0.005299
# 2017-02-14                   0.004076            0.009487
# 2015-12-31                  -0.002584           -0.003237
# 2015-10-29                  -0.001293            0.003685
# 2017-12-07                   0.002370           -0.000391
# 2017-05-25                   0.003091            0.001604
# 2017-02-17                   0.005239            0.001365
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2016-04-08                     0.009591                0.002218
# 2015-08-31                    -0.004977               -0.019650
# 2017-09-07                     0.000242                0.006670
# 2017-09-15                     0.001579               -0.001527
# 2017-02-14                     0.002747                0.001473
# 2015-12-31                    -0.010974               -0.006502
# 2015-10-29                     0.001309               -0.003634
# 2017-12-07                    -0.008949                0.009378
# 2017-05-25                     0.004110                0.008492
# 2017-02-17                     0.080705               -0.004561

# %%
whale_returns_csv.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833

# %%
whale_returns_csv.describe()
# Out:
#        SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# count                1059.000000         1059.000000
# mean                    0.000179           -0.000203
# std                     0.007842            0.006977
# min                    -0.032711           -0.032099
# 25%                    -0.003594           -0.003961
# 50%                     0.000467            0.000000
# 75%                     0.004292            0.003567
# max                     0.042977            0.029338
#
#        TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# count                  1059.000000             1059.000000
# mean                     -0.000081                0.000501
# std                       0.010824                0.012831
# min                      -0.139820               -0.066505
# 25%                      -0.004746               -0.005515
# 50%                       0.000232                0.000617
# 75%                       0.005176                0.007516
# max                       0.080705                0.061341

# %%
whale_returns_csv.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
whale_returns_csv.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
whale_returns_csv.isnull().mean() * 100
# Out:
# SOROS FUND MANAGEMENT LLC      0.09434
# PAULSON & CO.INC.              0.09434
# TIGER GLOBAL MANAGEMENT LLC    0.09434
# BERKSHIRE HATHAWAY INC         0.09434
# dtype: float64

# %%
whale_returns_csv.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns_csv = whale_returns_csv.dropna()
whale_returns_csv.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_returns_csv.duplicated(keep='first').sum()
# Out:
# 38

# %%
whale_returns_csv = whale_returns_csv.drop_duplicates()

# %%
whale_returns_csv.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1021
# PAULSON & CO.INC.              1021
# TIGER GLOBAL MANAGEMENT LLC    1021
# BERKSHIRE HATHAWAY INC         1021
# dtype: int64

# %%
algo_daily_returns_csv = pd.read_csv(algo_file_path, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
algo_daily_returns_csv.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo_daily_returns_csv.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
algo_daily_returns_csv.tail()
# Out:
#               Algo 1    Algo 2
# Date
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358

# %%
algo_daily_returns_csv.sample(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2015-07-02 -0.002005 -0.005172
# 2014-09-15  0.007320 -0.007407
# 2015-11-13  0.004208 -0.007261
# 2018-10-16  0.021950  0.018630
# 2017-09-05 -0.005177 -0.007195
# 2015-01-29 -0.001772  0.007040
# 2016-06-03  0.019975 -0.005710
# 2016-12-21  0.004278 -0.001962
# 2014-06-09 -0.005012  0.005668
# 2018-05-08 -0.001733  0.001310

# %%
algo_daily_returns_csv.describe()
# Out:
#             Algo 1       Algo 2
# count  1241.000000  1235.000000
# mean      0.000667     0.000341
# std       0.007972     0.008466
# min      -0.030951    -0.036937
# 25%      -0.003238    -0.003733
# 50%       0.000135     0.000581
# 75%       0.003978     0.005194
# max       0.098246     0.083734

# %%
algo_daily_returns_csv.dtypes
# Out:
# Algo 1    float64
# Algo 2    float64
# dtype: object

# %%
algo_daily_returns_csv.count()
# Out:
# Algo 1    1241
# Algo 2    1235
# dtype: int64

# %%
algo_daily_returns_csv.isnull().mean() * 100
# Out:
# Algo 1    0.000000
# Algo 2    0.483481
# dtype: float64

# %%
algo_daily_returns_csv.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_daily_returns_csv = algo_daily_returns_csv.dropna()

# %%
algo_daily_returns_csv.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_daily_returns_csv.duplicated(keep='first').sum()
# Out:
# 0

# %%
algo_daily_returns_csv.count()
# Out:
# Algo 1    1235
# Algo 2    1235
# dtype: int64

# %%
sp500_returns = pd.read_csv(sp500_file_path, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
sp500_returns.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
sp500_returns.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
sp500_returns.tail()
# Out:
#                Close
# Date
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49

# %%
sp500_returns = sp500_returns.sort_index()

# %%
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
sp500_returns.sample(10)
# Out:
#                Close
# Date
# 2016-04-19  $2100.80
# 2014-09-24  $1998.30
# 2015-09-25  $1931.34
# 2018-11-30  $2760.17
# 2015-10-28  $2090.35
# 2016-02-19  $1917.78
# 2013-10-11  $1703.20
# 2016-02-02  $1903.03
# 2017-02-01  $2279.55
# 2016-04-01  $2072.78

# %%
sp500_returns.describe()
# Out:
#            Close
# count       1649
# unique      1639
# top     $1920.03
# freq           2

# %%
sp500_returns.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_returns['Close'] = sp500_returns['Close'].str.replace('$', '' )
sp500_returns.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
sp500_returns['Close'] = sp500_returns['Close'].astype('float')
sp500_returns.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_returns.count()
# Out:
# Close    1649
# dtype: int64

# %%
sp500_returns.duplicated(keep='first').sum()
# Out:
# 10

# %%
sp500_returns = sp500_returns.drop_duplicates()
sp500_returns.count()
# Out:
# Close    1639
# dtype: int64

# %%
sp500_returns = sp500_returns.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
sp500_returns.isnull().mean() * 100
# Out:
# Close    0.061013
# dtype: float64

# %%
sp500_returns.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
sp500_returns = sp500_returns.dropna()
sp500_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
sp500_returns = sp500_returns.rename(columns = {'Close':'S&P 500'})
sp500_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
all_returns = pd.concat([whale_returns_csv, algo_daily_returns_csv, sp500_returns], axis =1 , join = 'inner')
all_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %%
all_returns.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
all_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500
# Date
# 2019-04-16  0.002899  0.000509
# 2019-04-17 -0.005228 -0.002274
# 2019-04-18 -0.001229  0.001579
# 2019-04-22 -0.001936  0.001012
# 2019-04-23  0.009622  0.008841

# %%
all_returns.index = pd.to_datetime(all_returns.index) 
all_returns.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
all_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# dtype: int64

# %%
all_returns.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# Algo 1                         float64
# Algo 2                         float64
# S&P 500                        float64
# dtype: object

# %%
all_returns.duplicated().sum()
# Out:
# 0

# %%
all_returns.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1005
# PAULSON & CO.INC.              1005
# TIGER GLOBAL MANAGEMENT LLC    1005
# BERKSHIRE HATHAWAY INC         1005
# Algo 1                         1005
# Algo 2                         1005
# S&P 500                        1005
# dtype: int64

# %%
all_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500
# Date
# 2019-04-16  0.002899  0.000509
# 2019-04-17 -0.005228 -0.002274
# 2019-04-18 -0.001229  0.001579
# 2019-04-22 -0.001936  0.001012
# 2019-04-23  0.009622  0.008841

# %%
all_returns.plot(title = 'Daily Returns', legend = True, figsize = (22,12))

# %%
cumulative_returns = (1 + all_returns).cumprod() 
cumulative_returns.plot(title = 'Cumulative Returns', legend = True, figsize =(22,12))

# %%
cumulative_returns_by_year = all_returns.groupby(all_returns.index.year).apply(lambda x: (1+x).cumprod() - 1)
annual_returns = cumulative_returns_by_year.groupby(cumulative_returns_by_year.index.year).last()
annual_returns.head()
# Out:
#       SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015                  -0.013231           -0.035512
# 2016                  -0.008781           -0.120673
# 2017                   0.140602           -0.070806
# 2018                  -0.142604           -0.107642
# 2019                   0.200247            0.096603
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# Date
# 2015                     0.026813                0.007337  0.216065 -0.045911
# 2016                     0.263650               -0.122137  0.134865  0.068303
# 2017                    -0.003590                0.475275 -0.005604  0.180239
# 2018                    -0.271209               -0.117084  0.177758 -0.139009
# 2019                    -0.038493                0.304057  0.152960  0.206432
#
#        S&P 500
# Date
# 2015 -0.010680
# 2016  0.083300
# 2017  0.202799
# 2018 -0.060491
# 2019  0.151889

# %%
annual_returns.loc[2017].sort_values(ascending = False)
# Out:
# BERKSHIRE HATHAWAY INC         0.475275
# S&P 500                        0.202799
# Algo 2                         0.180239
# SOROS FUND MANAGEMENT LLC      0.140602
# TIGER GLOBAL MANAGEMENT LLC   -0.003590
# Algo 1                        -0.005604
# PAULSON & CO.INC.             -0.070806
# Name: 2017, dtype: float64

# %%
cumulative_returns_by_month = all_returns.groupby(pd.Grouper(freq = 'M')).apply(lambda x: (1+x).cumprod() - 1)
monthly_returns = cumulative_returns_by_month.groupby(pd.Grouper(freq='M')).last()
monthly_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-31                   0.017207            0.011306
# 2015-04-30                   0.003248            0.016876
# 2015-05-31                   0.008094            0.019797
# 2015-06-30                  -0.014935           -0.007651
# 2015-07-31                  -0.014779           -0.018293
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-31                     0.009419                0.002310  0.012788
# 2015-04-30                     0.010373                0.011927 -0.007167
# 2015-05-31                    -0.001410                0.001002  0.005174
# 2015-06-30                    -0.014254               -0.008842 -0.002467
# 2015-07-31                     0.020172               -0.021668 -0.051560
#
#               Algo 2   S&P 500
# Date
# 2015-03-31 -0.000962 -0.023378
# 2015-04-30  0.009620  0.008521
# 2015-05-31 -0.005529 -0.000285
# 2015-06-30  0.002462 -0.021012
# 2015-07-31 -0.016582  0.019742

# %%
monthly_returns.loc['2018-12-31'].sort_values(ascending = False)
# Out:
# Algo 1                        -0.055161
# BERKSHIRE HATHAWAY INC        -0.089757
# PAULSON & CO.INC.             -0.091320
# S&P 500                       -0.091777
# SOROS FUND MANAGEMENT LLC     -0.095657
# Algo 2                        -0.119221
# TIGER GLOBAL MANAGEMENT LLC   -0.144032
# Name: 2018-12-31 00:00:00, dtype: float64

# %%
daily_std = all_returns.std().sort_values()
daily_std.head(10)
# Out:
# PAULSON & CO.INC.              0.007126
# Algo 1                         0.007672
# SOROS FUND MANAGEMENT LLC      0.008020
# Algo 2                         0.008329
# S&P 500                        0.008609
# TIGER GLOBAL MANAGEMENT LLC    0.010899
# BERKSHIRE HATHAWAY INC         0.013097
# dtype: float64

# %%
daily_std > daily_std[4]
# Out:
# PAULSON & CO.INC.              False
# Algo 1                         False
# SOROS FUND MANAGEMENT LLC      False
# Algo 2                         False
# S&P 500                        False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# dtype: bool

# %%
all_returns.plot(kind = 'box', figsize = (22,12), title = 'Portfolio Risk')

# %%
annualized_std = daily_std * np.sqrt(252)
annualized_std.head(10)
# Out:
# PAULSON & CO.INC.              0.113119
# Algo 1                         0.121793
# SOROS FUND MANAGEMENT LLC      0.127306
# Algo 2                         0.132223
# S&P 500                        0.136666
# TIGER GLOBAL MANAGEMENT LLC    0.173015
# BERKSHIRE HATHAWAY INC         0.207902
# dtype: float64

# %%
all_returns.rolling(window = 21).std().plot(title = '21 Day Rolling Standard Deviation', figsize= (22,12))

# %%
correlation = all_returns.corr()
correlation.head(10)
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.698448
# PAULSON & CO.INC.                             0.698448            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.568982            0.437306
# BERKSHIRE HATHAWAY INC                        0.753658            0.542352
# Algo 1                                        0.319894            0.266163
# Algo 2                                        0.841109            0.688212
# S&P 500                                       0.845195            0.677540
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.568982
# PAULSON & CO.INC.                               0.437306
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424546
# Algo 1                                          0.167658
# Algo 2                                          0.522955
# S&P 500                                         0.630243
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.753658  0.319894  0.841109
# PAULSON & CO.INC.                          0.542352  0.266163  0.688212
# TIGER GLOBAL MANAGEMENT LLC                0.424546  0.167658  0.522955
# BERKSHIRE HATHAWAY INC                     1.000000  0.288943  0.698347
# Algo 1                                     0.288943  1.000000  0.281854
# Algo 2                                     0.698347  0.281854  1.000000
# S&P 500                                    0.758088  0.274479  0.854255
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.845195
# PAULSON & CO.INC.            0.677540
# TIGER GLOBAL MANAGEMENT LLC  0.630243
# BERKSHIRE HATHAWAY INC       0.758088
# Algo 1                       0.274479
# Algo 2                       0.854255
# S&P 500                      1.000000

# %%
sns.heatmap(correlation, vmin = -1, vmax = 1, annot = True)

# %%
rolling_covariance = all_returns['BERKSHIRE HATHAWAY INC'].rolling(window = 60).cov(all_returns['S&P 500'])
print(covariance)
# Out:
# 5.835347932698347e-05

# %%
rolling_variance = all_returns['S&P 500'].rolling(window = 60).var()
print(variance)
# Out:
# 7.411777878693682e-05

# %%
rolling_berkshire_beta = rolling_covariance / rolling_variance
rolling_berkshire_beta.plot(figsize =(22,12), title = 'Rolling 60 Day Beta of Berkshire Hathaway Inc')

# %%
all_returns.ewm(halflife = 21).mean().plot(figsize = (23,12), title= 'Exponentially Weighted Average with 21 day half-life')

# %%
sharpe_ratios = (all_returns.mean() * 252) / annualized_std
sharpe_ratios.head(6)
# Out:
# Algo 1                       1.342415
# Algo 2                       0.488758
# BERKSHIRE HATHAWAY INC       0.595006
# PAULSON & CO.INC.           -0.519339
# S&P 500                      0.679363
# SOROS FUND MANAGEMENT LLC    0.335701
# dtype: float64

# %%
sharpe_ratios.plot(kind = 'bar', figsize = (22,12), title = 'Sharpe Ratios')

# %%
dominos_filepath = Path('../python_pandas_homework/historical_quotes_custom_portfolio/dominos_historical_data.csv')
jpm_filepath = Path('../python_pandas_homework/historical_quotes_custom_portfolio/jpm_historical_data.csv')
marvel_filepath = Path('../python_pandas_homework/historical_quotes_custom_portfolio/marvel_historical_data.csv')
nike_filepath = Path('../python_pandas_homework/historical_quotes_custom_portfolio/nike_historical_data.csv')
sarepta_therapeutics_filepath = Path('../python_pandas_homework/historical_quotes_custom_portfolio/sarepta_therapeutics_historical_data.csv')

# %%
dominos_csv = pd.read_csv(dominos_filepath, index_col = 'date', parse_dates = True, infer_datetime_format = True)
dominos_csv = dominos_csv.drop(columns =['volume','open','high','low'])
dominos_csv.head()
# Out:
#                       close
# date
# 2019-08-14 12:42:00  236.60
# 2019-08-13 00:00:00  240.60
# 2019-08-12 00:00:00  240.01
# 2019-08-09 00:00:00  247.83
# 2019-08-08 00:00:00  246.75

# %%
jpm_csv = pd.read_csv(jpm_filepath, index_col = 'date', parse_dates = True, infer_datetime_format = True)
jpm_csv = jpm_csv.drop(columns =['volume','open','high','low'])
jpm_csv.head()
# Out:
#                        close
# date
# 2019-08-14 12:34:00  105.075
# 2019-08-13 00:00:00  109.340
# 2019-08-12 00:00:00  107.680
# 2019-08-09 00:00:00  109.740
# 2019-08-08 00:00:00  109.860

# %%
marvel_csv = pd.read_csv(marvel_filepath, index_col = 'date', parse_dates = True, infer_datetime_format = True)
marvel_csv = marvel_csv.drop(columns =['volume','open','high','low'])
marvel_csv.head()
# Out:
#                       close
# date
# 2019-08-14 12:51:00  24.435
# 2019-08-13 00:00:00  25.140
# 2019-08-12 00:00:00  23.920
# 2019-08-09 00:00:00  24.720
# 2019-08-08 00:00:00  25.360

# %%
nike_csv = pd.read_csv(nike_filepath, index_col = 'date', parse_dates = True, infer_datetime_format = True)
nike_csv = nike_csv.drop(columns =['volume','open','high','low'])
nike_csv.head()
# Out:
#                      close
# date
# 2019-08-14 12:40:00  81.52
# 2019-08-13 00:00:00  83.32
# 2019-08-12 00:00:00  81.65
# 2019-08-09 00:00:00  81.98
# 2019-08-08 00:00:00  83.00

# %%
sarepta_therapeutics_csv = pd.read_csv(sarepta_therapeutics_filepath, index_col = 'date', parse_dates = True, infer_datetime_format = True)
sarepta_therapeutics_csv = sarepta_therapeutics_csv.drop(columns =['volume','open','high','low'])
sarepta_therapeutics_csv.head()
# Out:
#                       close
# date
# 2019-08-14 12:49:00  123.59
# 2019-08-13 00:00:00  126.15
# 2019-08-12 00:00:00  124.14
# 2019-08-09 00:00:00  126.11
# 2019-08-08 00:00:00  132.98

# %%
combined_df = pd.concat([dominos_csv,jpm_csv,marvel_csv,nike_csv,sarepta_therapeutics_csv], axis = 1, join = 'inner')
combined_df.columns = ['DPZ', 'JPM', 'MRVL','NKE','SRPT']
combined_df.head()
# Out:
#                DPZ     JPM   MRVL    NKE    SRPT
# date
# 2019-08-13  240.60  109.34  25.14  83.32  126.15
# 2019-08-12  240.01  107.68  23.92  81.65  124.14
# 2019-08-09  247.83  109.74  24.72  81.98  126.11
# 2019-08-08  246.75  109.86  25.36  83.00  132.98
# 2019-08-07  245.74  108.03  24.70  81.28  142.26

# %%
combined_df.tail()
# Out:
#               DPZ    JPM   MRVL     NKE   SRPT
# date
# 2014-08-19  75.15  57.56  13.49  39.255  22.36
# 2014-08-18  75.04  57.23  13.43  39.275  22.35
# 2014-08-15  74.55  56.75  13.33  38.565  22.47
# 2014-08-14  74.75  56.98  13.33  38.650  22.36
# 2014-08-13  74.49  56.72  13.26  38.625  22.35

# %%
combined_df.isnull().sum()
# Out:
# DPZ     0
# JPM     0
# MRVL    0
# NKE     0
# SRPT    0
# dtype: int64

# %%
combined_df.duplicated(keep ='first').sum()
# Out:
# 0

# %%
all_returns_custom = combined_df.pct_change()
all_returns_custom.head()
# Out:
#                  DPZ       JPM      MRVL       NKE      SRPT
# date
# 2019-08-13       NaN       NaN       NaN       NaN       NaN
# 2019-08-12 -0.002452 -0.015182 -0.048528 -0.020043 -0.015933
# 2019-08-09  0.032582  0.019131  0.033445  0.004042  0.015869
# 2019-08-08 -0.004358  0.001093  0.025890  0.012442  0.054476
# 2019-08-07 -0.004093 -0.016658 -0.026025 -0.020723  0.069785

# %%
all_returns_custom = all_returns_custom.dropna()
all_returns_custom.head()
# Out:
#                  DPZ       JPM      MRVL       NKE      SRPT
# date
# 2019-08-12 -0.002452 -0.015182 -0.048528 -0.020043 -0.015933
# 2019-08-09  0.032582  0.019131  0.033445  0.004042  0.015869
# 2019-08-08 -0.004358  0.001093  0.025890  0.012442  0.054476
# 2019-08-07 -0.004093 -0.016658 -0.026025 -0.020723  0.069785
# 2019-08-06 -0.013144  0.022216 -0.017409  0.000246  0.008787

# %%
all_returns_custom = all_returns_custom.sort_index()
all_returns_custom.head()
# Out:
#                  DPZ       JPM      MRVL       NKE      SRPT
# date
# 2014-08-13 -0.003478 -0.004563 -0.005251 -0.000647 -0.000447
# 2014-08-14  0.002683  0.004053  0.000000  0.002204 -0.004895
# 2014-08-15 -0.006530 -0.008387 -0.007446 -0.018078  0.005369
# 2014-08-18 -0.001464 -0.005733 -0.004448  0.000509 -0.000447
# 2014-08-19  0.006563 -0.001388 -0.003693 -0.005069  0.029466

# %%
weights = [1/5,1/5,1/5,1/5,1/5]
all_returns_custom = all_returns_custom.dot(weights)
all_returns_custom.head()
# Out:
# date
# 2014-08-13   -0.002877
# 2014-08-14    0.000809
# 2014-08-15   -0.007014
# 2014-08-18   -0.002316
# 2014-08-19    0.005176
# dtype: float64

# %%
all_returns_joined = pd.concat([all_returns,all_returns_custom], axis = 1, join = 'inner')
all_returns_joined.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500         0
# 2015-03-03 -0.000949 -0.004539 -0.013012
# 2015-03-04  0.002416 -0.004389 -0.005602
# 2015-03-05  0.004323  0.001196  0.017821
# 2015-03-06 -0.011460 -0.014174 -0.002702
# 2015-03-09  0.001303  0.003944  0.014459

# %%
all_returns_joined = all_returns_joined.rename(columns = {0:"Custom_Portfolio"})
all_returns_joined.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500  Custom_Portfolio
# 2015-03-03 -0.000949 -0.004539         -0.013012
# 2015-03-04  0.002416 -0.004389         -0.005602
# 2015-03-05  0.004323  0.001196          0.017821
# 2015-03-06 -0.011460 -0.014174         -0.002702
# 2015-03-09  0.001303  0.003944          0.014459

# %%
all_returns_joined.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500  Custom_Portfolio
# 2019-04-16  0.002899  0.000509         -0.017266
# 2019-04-17 -0.005228 -0.002274          0.002408
# 2019-04-18 -0.001229  0.001579          0.010266
# 2019-04-22 -0.001936  0.001012         -0.013027
# 2019-04-23  0.009622  0.008841         -0.014033

# %%
all_returns_joined.plot(kind = 'box', figsize = (22,12))

# %%
all_returns_joined_daily_std = all_returns_joined.std()
all_returns_joined_daily_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.008020
# PAULSON & CO.INC.              0.007126
# TIGER GLOBAL MANAGEMENT LLC    0.010899
# BERKSHIRE HATHAWAY INC         0.013097
# Algo 1                         0.007672
# Algo 2                         0.008329
# S&P 500                        0.008609
# Custom_Portfolio               0.017543
# dtype: float64

# %%
all_returns_joined_annualized_std = all_returns_joined_daily_std * np.sqrt(252)
all_returns_joined_annualized_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.127306
# PAULSON & CO.INC.              0.113119
# TIGER GLOBAL MANAGEMENT LLC    0.173015
# BERKSHIRE HATHAWAY INC         0.207902
# Algo 1                         0.121793
# Algo 2                         0.132223
# S&P 500                        0.136666
# Custom_Portfolio               0.278489
# dtype: float64

# %%
all_returns_joined.rolling(window = 21).std().plot(title = '21 Day Rolling Standard Deviation', figsize= (22,12))

# %%
custom_covariance = all_returns_joined['Custom_Portfolio'].cov(all_returns_joined['S&P 500'])
print(custom_covariance)
# Out:
# 4.423965651903747e-06

# %%
custom_variance = all_returns_joined['S&P 500'].var()
print(custom_variance)
# Out:
# 7.411777878693682e-05

# %%
custom_beta = custom_covariance / custom_variance
print(custom_beta)
# Out:
# 0.05968831937909433

# %%
custom_sharpe_ratios = (all_returns_joined.mean() * 252) / all_returns_joined_annualized_std
print(custom_sharpe_ratios)
# Out:
# SOROS FUND MANAGEMENT LLC      0.335701
# PAULSON & CO.INC.             -0.519339
# TIGER GLOBAL MANAGEMENT LLC   -0.055444
# BERKSHIRE HATHAWAY INC         0.595006
# Algo 1                         1.342415
# Algo 2                         0.488758
# S&P 500                        0.679363
# Custom_Portfolio              -0.334707
# dtype: float64

# %%
custom_sharpe_ratios.plot(kind ='bar' , figsize = (22,12), title ='Sharpe Ratios')
